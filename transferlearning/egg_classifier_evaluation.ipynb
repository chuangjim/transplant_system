# %%
import torch
torch.cuda.empty_cache()
from cocoonclassifier_class import MODEL
# import importlib
# importlib.reload(MODEL)
loss = "CE"
optimizer = "AdamW"
with torch.no_grad():
    cocoon = MODEL('resnet', 50, 16, 'finetune', loss, optimizer)
    cocoon.read_model('./models/finetune/resnet/bs_16_resnet_op_AdamW_ls_CE')
cocoon.read_test_data("D:/Desktop/莊詠竣/ml/data/after_aug/delta_day_3__train_test_mix/val", 2)
accuracy, recall, precision, f1_score = cocoon.test(predict=True)
# Out:
# C:\Users\h\AppData\Roaming\Python\Python39\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# C:\Users\h\AppData\Roaming\Python\Python39\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Desktop\莊詠竣\transplant_system\transplant_system\transferlearning\egg_classifier_evaluation.ipynb Cell 1 in <cell line: 12>()
#      <a href='vscode-notebook-cell:/d%3A/Desktop/%E8%8E%8A%E8%A9%A0%E7%AB%A3/transplant_system/transplant_system/transferlearning/egg_classifier_evaluation.ipynb#ch0000000?line=9'>10</a>     cocoon.read_model('./models/finetune/resnet/bs_16_resnet_op_AdamW_ls_CE')
#      <a href='vscode-notebook-cell:/d%3A/Desktop/%E8%8E%8A%E8%A9%A0%E7%AB%A3/transplant_system/transplant_system/transferlearning/egg_classifier_evaluation.ipynb#ch0000000?line=10'>11</a> cocoon.read_test_data("D:/Desktop/莊詠竣/ml/data/after_aug/delta_day_3__train_test_mix/val", 2)
# ---> <a href='vscode-notebook-cell:/d%3A/Desktop/%E8%8E%8A%E8%A9%A0%E7%AB%A3/transplant_system/transplant_system/transferlearning/egg_classifier_evaluation.ipynb#ch0000000?line=11'>12</a> accuracy, recall, precision, f1_score = cocoon.test(predict=True)
#
# File d:\Desktop\莊詠竣\transplant_system\transplant_system\transferlearning\cocoonclassifier_class.py:326, in MODEL.test(self, predict)
#     324 if predict:
#     325     for i in pred:
# --> 326         print(i)
#     327 img = torchvision.utils.make_grid(image,nrow=24)
#     328 img = img.numpy().transpose(1,2,0)
#
# File c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\torch\_tensor.py:338, in Tensor.__repr__(self, tensor_contents)
#     335     return handle_torch_function(Tensor.__repr__, (self,), self,
#     336                                  tensor_contents=tensor_contents)
#     337 # All strings are unicode in Python 3.
# --> 338 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\torch\_tensor_str.py:481, in _str(self, tensor_contents)
#     479 def _str(self, *, tensor_contents=None):
#     480     with torch.no_grad():
# --> 481         return _str_intern(self, tensor_contents=tensor_contents)
#
# File c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\torch\_tensor_str.py:447, in _str_intern(inp, tensor_contents)
#     445                     tensor_str = _tensor_str(self.to_dense(), indent)
#     446                 else:
# --> 447                     tensor_str = _tensor_str(self, indent)
#     449 if self.layout != torch.strided:
#     450     suffixes.append('layout=' + str(self.layout))
#
# File c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\torch\_tensor_str.py:271, in _tensor_str(self, indent)
#     269 else:
#     270     formatter = _Formatter(get_summarized_data(self) if summarize else self)
# --> 271     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\torch\_tensor_str.py:218, in _tensor_str_with_formatter(self, indent, summarize, formatter1, formatter2)
#     215 dim = self.dim()
#     217 if dim == 0:
# --> 218     return _scalar_str(self, formatter1, formatter2)
#     220 if dim == 1:
#     221     return _vector_str(self, indent, summarize, formatter1, formatter2)
#
# File c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\torch\_tensor_str.py:176, in _scalar_str(self, formatter1, formatter2)
#     174         return real_str + "+" + imag_str
#     175 else:
# --> 176     return formatter1.format(self.item())
#
# KeyboardInterrupt:

# %%
# Out:
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 1])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 1])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([1, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([1, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([1, 0])
# tensor([1, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 1])
# tensor([1, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([1, 0])
# tensor([1, 0])
# tensor([0, 1])
# tensor([1, 0])
# tensor([0, 0])
# tensor([0, 1])
# tensor([0, 1])
# tensor([1, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 1])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 1])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([1, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([1, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([1, 1])
# tensor([0, 1])
# tensor([0, 0])
# tensor([0, 0])
# tensor([1, 0])
# tensor([0, 1])
# tensor([0, 0])
# tensor([1, 0])
# tensor([0, 1])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 1])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 1])
# tensor([1, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([1, 1])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# tensor([0, 0])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Desktop\莊詠竣\transplant_system\transplant_system\transferlearning\egg_classifier_evaluation.ipynb Cell 2 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Desktop/%E8%8E%8A%E8%A9%A0%E7%AB%A3/transplant_system/transplant_system/transferlearning/egg_classifier_evaluation.ipynb#ch0000001?line=0'>1</a> cocoon.read_test_data("D:/Desktop/莊詠竣/ml/data/after_aug/delta_day_3__train_test_mix/val", 2)
# ----> <a href='vscode-notebook-cell:/d%3A/Desktop/%E8%8E%8A%E8%A9%A0%E7%AB%A3/transplant_system/transplant_system/transferlearning/egg_classifier_evaluation.ipynb#ch0000001?line=1'>2</a> accuracy, recall, precision, f1_score = cocoon.test(predict=True)
#
# File d:\Desktop\莊詠竣\transplant_system\transplant_system\transferlearning\cocoonclassifier_class.py:325, in MODEL.test(self, predict)
#     323 _, pred = torch.max(y_pred.data, 1)
#     324 if predict:
# --> 325     print(pred)
#     326 img = torchvision.utils.make_grid(image,nrow=24)
#     327 img = img.numpy().transpose(1,2,0)
#
# File c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\torch\_tensor.py:338, in Tensor.__repr__(self, tensor_contents)
#     335     return handle_torch_function(Tensor.__repr__, (self,), self,
#     336                                  tensor_contents=tensor_contents)
#     337 # All strings are unicode in Python 3.
# --> 338 return torch._tensor_str._str(self, tensor_contents=tensor_contents)
#
# File c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\torch\_tensor_str.py:481, in _str(self, tensor_contents)
#     479 def _str(self, *, tensor_contents=None):
#     480     with torch.no_grad():
# --> 481         return _str_intern(self, tensor_contents=tensor_contents)
#
# File c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\torch\_tensor_str.py:447, in _str_intern(inp, tensor_contents)
#     445                     tensor_str = _tensor_str(self.to_dense(), indent)
#     446                 else:
# --> 447                     tensor_str = _tensor_str(self, indent)
#     449 if self.layout != torch.strided:
#     450     suffixes.append('layout=' + str(self.layout))
#
# File c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\torch\_tensor_str.py:270, in _tensor_str(self, indent)
#     268     return _tensor_str_with_formatter(self, indent, summarize, real_formatter, imag_formatter)
#     269 else:
# --> 270     formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     271     return _tensor_str_with_formatter(self, indent, summarize, formatter)
#
# File c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\torch\_tensor_str.py:99, in _Formatter.__init__(self, tensor)
#      97 if not self.floating_dtype:
#      98     for value in tensor_view:
# ---> 99         value_str = '{}'.format(value)
#     100         self.max_width = max(self.max_width, len(value_str))
#     102 else:
#
# File c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\torch\_tensor.py:659, in Tensor.__format__(self, format_spec)
#     657     return handle_torch_function(Tensor.__format__, (self,), self, format_spec)
#     658 if self.dim() == 0 and not self.is_meta:
# --> 659     return self.item().__format__(format_spec)
#     660 return object.__format__(self, format_spec)
#
# KeyboardInterrupt:

# %%
    print(path)
# Out:
# d:\Desktop\莊詠竣\transplant_system\transplant_system\transferlearning
# c:\Users\h\anaconda3\envs\lacewing\python39.zip
# c:\Users\h\anaconda3\envs\lacewing\DLLs
# c:\Users\h\anaconda3\envs\lacewing\lib
# c:\Users\h\anaconda3\envs\lacewing
#
# c:\Users\h\anaconda3\envs\lacewing\lib\site-packages
# c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\win32
# c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\win32\lib
# c:\Users\h\anaconda3\envs\lacewing\lib\site-packages\Pythonwin
